# %%
import tifffile as tiff
import matplotlib.pyplot as plt

img1 = tiff.imread('/home/hh/container/code/fusion/results/stfdiff/STIL/model6_BN_ReLU/Inference~Adam_1e-3~PredNoiseNet_64_depth_3~timesteps_100~ddim_50~pred_x0/STIL_Test/imgs/STIL/0/save_img/L1-Fall_Scene_79_28.tif')
plt.figure(figsize=(10,10))
plt.imshow(img1[:,:,(3,2,1)])

img2 = tiff.imread('/home/hh/container/code/fusion/data/spatio_temporal_fusion/Mini_STIF_Dataset/STIL_Test/M2/Fall_Scene_106_48.tif')
plt.figure(figsize=(10,10))
plt.imshow(img2[:,:,(3,2,1)])

# %%
(img1-img2).max()
# Out:
# 1.4901161e-08
